# %%
# %scala

spark

# %%
# %sql
SELECT current_catalog();

# %%
# %sql
USE CATALOG hive_metastore;

# %%
# %sql
show catalogs;

# %%
# %sql
create schema bronze

# %%
# %sql
-- managed table
create table bronze.emp(
  emp_id int,
  emp_name varchar(30),
  dept_code string
);

# %%
# %sql desc bronze.emp

# %%
# %sql drop table bronze.emp

# %%
# %sql 
desc extended bronze.emp

# %%
# %sql
insert into bronze.emp(emp_id,emp_name,dept_code) values (1,'Ajit', 'dept001'),
(2,'Aman', 'dept002'),
(3,'Anil', 'dept001'),
(4,'Amit', 'dept003')

# %%
# %sql
select * from bronze.emp

# %%
dbutils.fs.ls('dbfs:/user/hive/warehouse/bronze.db/emp')

# %%
# %sql
create table bronze.emp_ext(
  emp_id int,
  emp_name varchar(30),
  dept_code string
)
LOCATION "dbfs:/tmp/emp_ext"

# %%
# %sql

desc extended bronze.emp_ext

# %%
# %sql
insert into bronze.emp_ext(emp_id,emp_name,dept_code) values (1,'Ajit', 'dept001'),
(2,'Aman', 'dept002'),
(3,'Anil', 'dept001'),
(4,'Amit', 'dept003')

# %%
# %sql 
desc extended bronze.emp_ext

# %%
dbutils.fs.ls('dbfs:/tmp/emp_ext')

# %%
# %sql
drop table bronze.emp

# %%
# %sql
drop table bronze.emp_ext

# %%
dbutils.fs.ls('dbfs:/user/hive/warehouse/bronze.db/emp')

# %%
# %sql
select * from bronze.emp_ext

# %%
# %sql
create view bronze.emp_ve as 
SELECT * from bronze.emp_ext WHERE dept_code = 'dept001'

# %%
# %sql
select * from bronze.emp_ve

# %%
# %sql
