# %%
# %sql
-- create table in dev catalog
create table dev.bronze.SALE_MANAGED(
  invoice_id String,
  cust_id String,
  product_code String,
  QTY double,
  PRICE Double
);

--insert data
insert into dev.bronze.SALE_MANAGED values ('INV0001', 'CUST1001', 'PCODE1001',10,100)

# %%
# %sql
-- create external table in dev catalog
create table dev.bronze.SALE_EXTERNAL(
  invoice_id String,
  cust_id String,
  product_code String,
  QTY double,
  PRICE Double
)
LOCATION 'abfss://unity-catalog-data@kaimurservicesdevdata.dfs.core.windows.net/adb/ext_tables/sales_external';

--insert data
insert into dev.bronze.SALE_EXTERNAL values ('INV0001', 'CUST1001', 'PCODE1001',10,100)

# %%
# %sql 
describe extended dev.bronze.SALE_MANAGED

# %%
# %sql describe extended dev.bronze.SALE_EXTERNAL

# %%
# %sql
-- in case of unity catalog whenever a data drop both data as well as meta data gone but data delete in some time may may 7-30 days but in hive meta store data deleted imeditaly. so in unity catalog within 7 days you can undrop tbale get same data

# %%
# %sql
drop table dev.bronze.sale_external;

# %%
# %sql
drop table dev.bronze.sale_managed;

# %%
# %sql
desc extended dev.bronze.sale_managed

# %%
# %sql
undrop table dev.bronze.sale_managed;

# %%
# %sql
desc extended dev.bronze.sale_managed

# %%
# %sql
use catalog dev;
show tables in bronze;

# %%
# %sql
use catalog dev;
show tables dropped in bronze;

# %%
# %sql
undrop table with id '68a827df-82c5-4107-b7d4-0dc3def6cdae'

# %%
# %sql
use catalog dev;
show tables in bronze;
