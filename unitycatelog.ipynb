# %%
# %sql
SHOW CATALOGS;

# %%
# %sql
--CREATE SCHEMA IF NOT EXISTS default.bronze

# %%
# %sql

DESCRIBE CATALOG extended dev

# %%
# %sql
Create Catalog dev_sql

# %%
# %sql 
describe catalog extended dev_sql

# %%
# %sql
drop catalog dev_sql cascade

# %%
# %sql
--describe catalog dev_sql

# %%
display(dbutils.fs.ls("dbfs:/"))

# %%
# %sql
Create external location `ext_loc`
URL 'abfss://unity-catalog-storage@dbstorageedrtnr744rhos.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL `storage_cred`)

# %%
dbutils.fs.ls("abfss://unity-catalog-storage@dbstorageedrtnr744rhos.dfs.core.windows.net/")

# %%
# %sql
-- create catlog with external location for manged table
Create catalog dev_ext
managed location 'abfss://unity-catalog-storage@dbstorageedrtnr744rhos.dfs.core.windows.net/' comment 'This is external storage catalog'

# %%
# %sql
describe catalog extended dev_ext

# %%
# %sql
-- Create schema without external location in dev catalog
Create schema dev.bronze
comment 'this is bronze schema'

# %%
# %sql
-- Create schema with external location in dev_ext catalog
Create schema dev_ext.bronze
comment 'this is bronze schema without external location at schema level'

# %%
# %sql
create external location ext_ksadls
URL 'abfss://unity-catalog-data@kaimurservicesdevdata.dfs.core.windows.net/adb/schema'
with (storage credential `ksalds_cred`)

# %%
# %sql
-- Create schema and specify external location at schema level in dev_ext catalog
create schema if not exists dev_ext.bronze_ext
managed location 'abfss://unity-catalog-data@kaimurservicesdevdata.dfs.core.windows.net/adb/schema'
comment 'created schema in dev_ext with specfied location at schema level'

# %%
# %sql
-- create table in dev catalog
-- create table dev.bronze.RAW_SALE(
--   invoice_id String,
--   cust_id String,
--   product_code String,
--   QTY double,
--   PRICE Double
-- )

--insert data
insert into dev.bronze.RAW_SALE values ('INV0001', 'CUST1001', 'PCODE1001',10,100)

# %%
# %sql
-- create table in dev catalog
-- create table dev_ext.bronze.RAW_SALE(
--   invoice_id String,
--   cust_id String,
--   product_code String,
--   QTY double,
--   PRICE Double
-- );

--insert data
insert into dev_ext.bronze.RAW_SALE values ('INV0001', 'CUST1001', 'PCODE1001',10,100)

# %%
# %sql
-- create table in dev catalog
create table dev_ext.bronze_ext.RAW_SALE(
--   invoice_id String,
--   cust_id String,
--   product_code String,
--   QTY double,
--   PRICE Double
-- );

--insert data
insert into dev_ext.bronze_ext.RAW_SALE values ('INV0001', 'CUST1001', 'PCODE1001',10,100)

# %%
# %sql
describe extended dev.bronze.RAW_SALE

# %%
# %sql
describe extended dev_ext.bronze.RAW_SALE

# %%
# %sql
describe extended dev_ext.bronze_ext.RAW_SALE
